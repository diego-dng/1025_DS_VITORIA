# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %%
# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, None, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, None, 3, None, 2, None, 2, None, None, 1, 2, None],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

import math

# %% [markdown]
# ### Step 1. This is the data given as a dictionary. Create a dataframe and assign it to a variable called army.

# %%
army = pd.DataFrame(raw_data)

# %%
army
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st   523.0        5  1045         1        1.0        1
# 1   Nighthawks     1st    52.0       42   957         5        NaN        0
# 2   Nighthawks     2nd    25.0        2  1099        62        3.0        1
# 3   Nighthawks     2nd   616.0        2  1400        26        NaN        1
# 4     Dragoons     1st    43.0        4  1592        73        2.0        0
# 5     Dragoons     1st   234.0        7  1006        37        NaN        1
# 6     Dragoons     2nd   523.0        8   987       949        2.0        0
# 7     Dragoons     2nd    62.0        3   849        48        NaN        1
# 8       Scouts     1st     NaN        4   973        48        NaN        0
# 9       Scouts     1st    73.0        7  1005       435        1.0        0
# 10      Scouts     2nd    37.0        8  1099        63        2.0        1
# 11      Scouts     2nd    35.0        9  1523       345        NaN        1
#
#     deserters      origin
# 0           4     Arizona
# 1          24  California
# 2          31       Texas
# 3           2     Florida
# 4           3       Maine
# 5           4        Iowa
# 6          24      Alaska
# 7          31  Washington
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %%
army.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   regiment   12 non-null     object
#  1   company    12 non-null     object
#  2   deaths     11 non-null     float64
#  3   battles    12 non-null     int64
#  4   size       12 non-null     int64
#  5   veterans   12 non-null     int64
#  6   readiness  6 non-null      float64
#  7   armored    12 non-null     int64
#  8   deserters  12 non-null     int64
#  9   origin     12 non-null     object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 1.1+ KB

# %% [markdown]
# ### Step 2. Check missing values

# %%
army.isnull()
# Out:
#     regiment  company  deaths  battles   size  veterans  readiness  armored  \
# 0      False    False   False    False  False     False      False    False
# 1      False    False   False    False  False     False       True    False
# 2      False    False   False    False  False     False      False    False
# 3      False    False   False    False  False     False       True    False
# 4      False    False   False    False  False     False      False    False
# 5      False    False   False    False  False     False       True    False
# 6      False    False   False    False  False     False      False    False
# 7      False    False   False    False  False     False       True    False
# 8      False    False    True    False  False     False       True    False
# 9      False    False   False    False  False     False      False    False
# 10     False    False   False    False  False     False      False    False
# 11     False    False   False    False  False     False       True    False
#
#     deserters  origin
# 0       False   False
# 1       False   False
# 2       False   False
# 3       False   False
# 4       False   False
# 5       False   False
# 6       False   False
# 7       False   False
# 8       False   False
# 9       False   False
# 10      False   False
# 11      False   False

# %%
army[(army["regiment"] == "Dragoons") & (army["readiness"].isnull())]
# Out:
#    regiment company  deaths  battles  size  veterans  readiness  armored  \
# 5  Dragoons     1st   234.0        7  1006        37        NaN        1
# 7  Dragoons     2nd    62.0        3   849        48        NaN        1
#
#    deserters      origin
# 5          4        Iowa
# 7         31  Washington

# %% [markdown]
# ### Step 3. Drop features, if there are more than 30% missing values.

# %%
math.ceil(len(army) * 0.7)
# Out:
# 9

# %%
army.dropna(thresh= len(army) * 0.7,axis=1, inplace= True)

# %%
army
# Out:
#       regiment company  deaths  battles  size  veterans  armored  deserters  \
# 0   Nighthawks     1st   523.0        5  1045         1        1          4
# 1   Nighthawks     1st    52.0       42   957         5        0         24
# 2   Nighthawks     2nd    25.0        2  1099        62        1         31
# 3   Nighthawks     2nd   616.0        2  1400        26        1          2
# 4     Dragoons     1st    43.0        4  1592        73        0          3
# 5     Dragoons     1st   234.0        7  1006        37        1          4
# 6     Dragoons     2nd   523.0        8   987       949        0         24
# 7     Dragoons     2nd    62.0        3   849        48        1         31
# 8       Scouts     1st     NaN        4   973        48        0          2
# 9       Scouts     1st    73.0        7  1005       435        0          3
# 10      Scouts     2nd    37.0        8  1099        63        1          2
# 11      Scouts     2nd    35.0        9  1523       345        1          3
#
#         origin
# 0      Arizona
# 1   California
# 2        Texas
# 3      Florida
# 4        Maine
# 5         Iowa
# 6       Alaska
# 7   Washington
# 8       Oregon
# 9      Wyoming
# 10    Louisana
# 11     Georgia

# %% [markdown]
# ### Step 4. Fill missing values with the mean of their regiment.

# %%
army
# Out:
#       regiment company  deaths  battles  size  veterans  armored  deserters  \
# 0   Nighthawks     1st   523.0        5  1045         1        1          4
# 1   Nighthawks     1st    52.0       42   957         5        0         24
# 2   Nighthawks     2nd    25.0        2  1099        62        1         31
# 3   Nighthawks     2nd   616.0        2  1400        26        1          2
# 4     Dragoons     1st    43.0        4  1592        73        0          3
# 5     Dragoons     1st   234.0        7  1006        37        1          4
# 6     Dragoons     2nd   523.0        8   987       949        0         24
# 7     Dragoons     2nd    62.0        3   849        48        1         31
# 8       Scouts     1st     NaN        4   973        48        0          2
# 9       Scouts     1st    73.0        7  1005       435        0          3
# 10      Scouts     2nd    37.0        8  1099        63        1          2
# 11      Scouts     2nd    35.0        9  1523       345        1          3
#
#         origin
# 0      Arizona
# 1   California
# 2        Texas
# 3      Florida
# 4        Maine
# 5         Iowa
# 6       Alaska
# 7   Washington
# 8       Oregon
# 9      Wyoming
# 10    Louisana
# 11     Georgia

# %%
army["deaths"].fillna(0)
# Out:
# 0     523.0
# 1      52.0
# 2      25.0
# 3     616.0
# 4      43.0
# 5     234.0
# 6     523.0
# 7      62.0
# 8       0.0
# 9      73.0
# 10     37.0
# 11     35.0
# Name: deaths, dtype: float64

# %%
army["deaths"].mean()
# Out:
# np.float64(202.0909090909091)

# %%
army["deaths"].fillna(army["deaths"].mean())
# Out:
# 0     523.000000
# 1      52.000000
# 2      25.000000
# 3     616.000000
# 4      43.000000
# 5     234.000000
# 6     523.000000
# 7      62.000000
# 8     202.090909
# 9      73.000000
# 10     37.000000
# 11     35.000000
# Name: deaths, dtype: float64

# %%
army.groupby("regiment")["deaths"].mean()["Scouts"]
# Out:
# regiment
# Dragoons      215.500000
# Nighthawks    304.000000
# Scouts         48.333333
# Name: deaths, dtype: float64

# %%
valor_media = round(army.groupby("regiment")["deaths"].mean()["Scouts"])
valor_media
# Out:
# 48

# %%
army["deaths"] = army["deaths"].fillna(valor_media)

# %%
army
# Out:
#       regiment company  deaths  battles  size  veterans  armored  deserters  \
# 0   Nighthawks     1st   523.0        5  1045         1        1          4
# 1   Nighthawks     1st    52.0       42   957         5        0         24
# 2   Nighthawks     2nd    25.0        2  1099        62        1         31
# 3   Nighthawks     2nd   616.0        2  1400        26        1          2
# 4     Dragoons     1st    43.0        4  1592        73        0          3
# 5     Dragoons     1st   234.0        7  1006        37        1          4
# 6     Dragoons     2nd   523.0        8   987       949        0         24
# 7     Dragoons     2nd    62.0        3   849        48        1         31
# 8       Scouts     1st    48.0        4   973        48        0          2
# 9       Scouts     1st    73.0        7  1005       435        0          3
# 10      Scouts     2nd    37.0        8  1099        63        1          2
# 11      Scouts     2nd    35.0        9  1523       345        1          3
#
#         origin
# 0      Arizona
# 1   California
# 2        Texas
# 3      Florida
# 4        Maine
# 5         Iowa
# 6       Alaska
# 7   Washington
# 8       Oregon
# 9      Wyoming
# 10    Louisana
# 11     Georgia

# %% [markdown]
# ### Step 5. Set the 'origin' colum as the index of the dataframe

# %%
army = army.set_index("origin")

# %%
army
# Out:
#               regiment company  deaths  battles  size  veterans  armored  \
# origin
# Arizona     Nighthawks     1st   523.0        5  1045         1        1
# California  Nighthawks     1st    52.0       42   957         5        0
# Texas       Nighthawks     2nd    25.0        2  1099        62        1
# Florida     Nighthawks     2nd   616.0        2  1400        26        1
# Maine         Dragoons     1st    43.0        4  1592        73        0
# Iowa          Dragoons     1st   234.0        7  1006        37        1
# Alaska        Dragoons     2nd   523.0        8   987       949        0
# Washington    Dragoons     2nd    62.0        3   849        48        1
# Oregon          Scouts     1st    48.0        4   973        48        0
# Wyoming         Scouts     1st    73.0        7  1005       435        0
# Louisana        Scouts     2nd    37.0        8  1099        63        1
# Georgia         Scouts     2nd    35.0        9  1523       345        1
#
#             deserters
# origin
# Arizona             4
# California         24
# Texas              31
# Florida             2
# Maine               3
# Iowa                4
# Alaska             24
# Washington         31
# Oregon              2
# Wyoming             3
# Louisana            2
# Georgia             3

# %% [markdown]
# ### Step 6. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
army.loc[["Maine", "Alaska"], ["deaths", "size", "deserters"]]
# Out:
#         deaths  size  deserters
# origin
# Maine     43.0  1592          3
# Alaska   523.0   987         24

# %% [markdown]
# ### Step 7. Select the rows 3 to 7 and the columns 3 to 6

# %%
army.iloc[2:7, 2:6]
# Out:
#          deaths  battles  size  veterans
# origin
# Texas      25.0        2  1099        62
# Florida   616.0        2  1400        26
# Maine      43.0        4  1592        73
# Iowa      234.0        7  1006        37
# Alaska    523.0        8   987       949

# %% [markdown]
# ### Step 8. Select every row after the fourth row and all columns

# %%
army.iloc[4:]
# Out:
#             regiment company  deaths  battles  size  veterans  armored  \
# origin
# Maine       Dragoons     1st    43.0        4  1592        73        0
# Iowa        Dragoons     1st   234.0        7  1006        37        1
# Alaska      Dragoons     2nd   523.0        8   987       949        0
# Washington  Dragoons     2nd    62.0        3   849        48        1
# Oregon        Scouts     1st    48.0        4   973        48        0
# Wyoming       Scouts     1st    73.0        7  1005       435        0
# Louisana      Scouts     2nd    37.0        8  1099        63        1
# Georgia       Scouts     2nd    35.0        9  1523       345        1
#
#             deserters
# origin
# Maine               3
# Iowa                4
# Alaska             24
# Washington         31
# Oregon              2
# Wyoming             3
# Louisana            2
# Georgia             3

# %% [markdown]
# ### Step 9. Select every row up to the 4th row and all columns

# %%
army.iloc[:4]
# Out:
#               regiment company  deaths  battles  size  veterans  armored  \
# origin
# Arizona     Nighthawks     1st   523.0        5  1045         1        1
# California  Nighthawks     1st    52.0       42   957         5        0
# Texas       Nighthawks     2nd    25.0        2  1099        62        1
# Florida     Nighthawks     2nd   616.0        2  1400        26        1
#
#             deserters
# origin
# Arizona             4
# California         24
# Texas              31
# Florida             2

# %% [markdown]
# ### Step 10. Select the 3rd column up to the 7th column

# %%
army.iloc[:, 2:7]
# Out:
#             deaths  battles  size  veterans  armored
# origin
# Arizona      523.0        5  1045         1        1
# California    52.0       42   957         5        0
# Texas         25.0        2  1099        62        1
# Florida      616.0        2  1400        26        1
# Maine         43.0        4  1592        73        0
# Iowa         234.0        7  1006        37        1
# Alaska       523.0        8   987       949        0
# Washington    62.0        3   849        48        1
# Oregon        48.0        4   973        48        0
# Wyoming       73.0        7  1005       435        0
# Louisana      37.0        8  1099        63        1
# Georgia       35.0        9  1523       345        1

# %% [markdown]
# ### Step 11. Select rows where df.deaths is greater than 50

# %%
mascara = army["deaths"] > 50

# %%
army[mascara]
# Out:
#               regiment company  deaths  battles  size  veterans  armored  \
# origin
# Arizona     Nighthawks     1st   523.0        5  1045         1        1
# California  Nighthawks     1st    52.0       42   957         5        0
# Florida     Nighthawks     2nd   616.0        2  1400        26        1
# Iowa          Dragoons     1st   234.0        7  1006        37        1
# Alaska        Dragoons     2nd   523.0        8   987       949        0
# Washington    Dragoons     2nd    62.0        3   849        48        1
# Wyoming         Scouts     1st    73.0        7  1005       435        0
#
#             deserters
# origin
# Arizona             4
# California         24
# Florida             2
# Iowa                4
# Alaska             24
# Washington         31
# Wyoming             3

# %% [markdown]
# ### Step 12. Select rows where df.deaths is greater than 500 or less than 50

# %%
mascara = (army["deaths"] <50) | (army["deaths"] >500)
mascara
# Out:
# origin
# Arizona        True
# California    False
# Texas          True
# Florida        True
# Maine          True
# Iowa          False
# Alaska         True
# Washington    False
# Oregon         True
# Wyoming       False
# Louisana       True
# Georgia        True
# Name: deaths, dtype: bool

# %%
army[mascara]
# Out:
#             regiment company  deaths  battles  size  veterans  armored  \
# origin
# Arizona   Nighthawks     1st   523.0        5  1045         1        1
# Texas     Nighthawks     2nd    25.0        2  1099        62        1
# Florida   Nighthawks     2nd   616.0        2  1400        26        1
# Maine       Dragoons     1st    43.0        4  1592        73        0
# Alaska      Dragoons     2nd   523.0        8   987       949        0
# Oregon        Scouts     1st    48.0        4   973        48        0
# Louisana      Scouts     2nd    37.0        8  1099        63        1
# Georgia       Scouts     2nd    35.0        9  1523       345        1
#
#           deserters
# origin
# Arizona           4
# Texas            31
# Florida           2
# Maine             3
# Alaska           24
# Oregon            2
# Louisana          2
# Georgia           3

# %% [markdown]
# ### Step 13. Select all the regiments not named "Dragoons"

# %%
army[army["regiment"] != "Dragoons"]
# Out:
#               regiment company  deaths  battles  size  veterans  armored  \
# origin
# Arizona     Nighthawks     1st   523.0        5  1045         1        1
# California  Nighthawks     1st    52.0       42   957         5        0
# Texas       Nighthawks     2nd    25.0        2  1099        62        1
# Florida     Nighthawks     2nd   616.0        2  1400        26        1
# Oregon          Scouts     1st    48.0        4   973        48        0
# Wyoming         Scouts     1st    73.0        7  1005       435        0
# Louisana        Scouts     2nd    37.0        8  1099        63        1
# Georgia         Scouts     2nd    35.0        9  1523       345        1
#
#             deserters
# origin
# Arizona             4
# California         24
# Texas              31
# Florida             2
# Oregon              2
# Wyoming             3
# Louisana            2
# Georgia             3

# %% [markdown]
# ### Step 14. Select the rows called Texas and Arizona

# %%
army.loc[["Texas", "Arizona"]]
# Out:
#            regiment company  deaths  battles  size  veterans  armored  \
# origin
# Texas    Nighthawks     2nd    25.0        2  1099        62        1
# Arizona  Nighthawks     1st   523.0        5  1045         1        1
#
#          deserters
# origin
# Texas           31
# Arizona          4

# %% [markdown]
# ### Step 15. Select the third cell in the row named Arizona

# %%
army.loc["Arizona"][2]
# Out:
# C:\Users\Diego Nuñez\AppData\Local\Temp\ipykernel_17208\822538043.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   army.loc["Arizona"][2]
# np.float64(523.0)

# %% [markdown]
# ### Step 16. Select the third cell down in the column named deaths

# %%
army["deaths"][2]
# Out:
# C:\Users\Diego Nuñez\AppData\Local\Temp\ipykernel_17208\1690644052.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   army["deaths"][2]
# np.float64(25.0)
