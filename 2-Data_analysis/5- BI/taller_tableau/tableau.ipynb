# %% [markdown]
# # Tableau.

# %% [markdown]
# | Bloque                                 | Contenido                                               | Actividad práctica                       |
# | -------------------------------------- | ------------------------------------------------------- | ---------------------------------------- |
# | **1. Introducción a Tableau**          | Qué es Tableau, tipos de licencias, interfaz principal  | Recorrido guiado del entorno             |
# | **2. Conexión y preparación de datos** | Conexión a Excel / CSV, tipos de datos, limpieza básica | Importar dataset y explorar campos       |
# | **3. Creación de visualizaciones**     | Gráficos básicos (barras, líneas, mapas, dispersión)    | Crear 3 gráficos con datos reales        |
# | **4. Dashboards e interactividad**     | Filtros, acciones, diseño y formato                     | Crear un dashboard combinando las vistas |
# | **5. Storytelling y presentación**     | Cómo comunicar con datos, diseño visual                 | Exposición breve de dashboards           |
# | **6. Cierre y evaluación**             | Preguntas, conclusiones, feedback                       | Cuestionario o mini reto                 |

# %% [markdown]
# ## 1. Introducción a Tableau.

# %% [markdown]
# Tableau es una herramienta de Business Intelligence (BI) y visualización de datos que permite analizar, explorar y comunicar información de manera visual e interactiva.
#
# Su principal fortaleza es que convierte datos en gráficos, mapas y dashboards dinámicos sin necesidad de programar, ayudando a descubrir patrones, tendencias y relaciones en los datos.
#
# En otras palabras:
#
# Tableau transforma los datos en historias visuales que facilitan la toma de decisiones basada en evidencia.
#
# ### ¿Para qué se usa Tableau?
#
# Tableau se utiliza en una amplia variedad de contextos, tanto empresariales como académicos:
#
# - 📊 Análisis de datos: explora grandes volúmenes de información de manera rápida y visual.
#
# - 💡 Toma de decisiones: ayuda a directivos y analistas a interpretar resultados mediante dashboards claros.
#
# - 🌍 Visualización geográfica: crea mapas interactivos y análisis espaciales.
#
# - 🧩 Integración de fuentes: combina datos de Excel, bases SQL, Google Sheets, o plataformas en la nube.
#
# - 🧑‍🏫 Educación y proyectos: facilita el aprendizaje de análisis visual, storytelling y pensamiento analítico.

# %% [markdown]
# 🌐 Tableau Public (gratuito): https://public.tableau.com
#
# 💻 Versión de prueba de Tableau Desktop (14 días): https://www.tableau.com/es-es/products/trial

# %% [markdown]
# | Versión / Producto                 | Descripción                                                                                   | Ideal para                                                                       |
# | ---------------------------------- | --------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------------- |
# | **Tableau Desktop**                | Aplicación de escritorio profesional para crear visualizaciones y dashboards completos.       | Analistas, docentes o profesionales que trabajan localmente.                     |
# | **Tableau Public**                 | Versión gratuita en línea. Permite crear y publicar dashboards en la nube (de forma pública). | Estudiantes, principiantes o quienes quieran compartir visualizaciones abiertas. |
# | **Tableau Prep**                   | Herramienta para limpiar, transformar y preparar datos antes de analizarlos.                  | Usuarios que necesitan depurar datos antes de visualizarlos.                     |
# | **Tableau Server / Tableau Cloud** | Plataformas para compartir, administrar y colaborar en dashboards dentro de organizaciones.   | Empresas o equipos que trabajan con datos compartidos.                           |
# | **Tableau Reader**                 | Aplicación gratuita para abrir y visualizar dashboards creados con Tableau Desktop.           | Usuarios que solo necesitan explorar visualizaciones sin editarlas.              |

# %% [markdown]
# ## 2. Conexión y preparación de datos

# %% [markdown]
# | Tipo de fuente               | Ejemplo                                        | Descripción                                                       |
# | ---------------------------- | ---------------------------------------------- | ----------------------------------------------------------------- |
# | **Archivos locales**         | Excel, CSV, JSON, PDF                          | Conexiones rápidas y directas desde tu equipo.                    |
# | **Bases de datos**           | MySQL, SQL Server, PostgreSQL, Oracle          | Ideal para análisis empresariales con grandes volúmenes de datos. |
# | **Fuentes en la nube**       | Google Sheets, Snowflake, Salesforce, BigQuery | Permiten trabajar con datos actualizados en línea.                |
# | **Datos web o estadísticos** | Conexiones a APIs, web data connectors         | Integración avanzada para datos externos.                         |

# %% [markdown]
# ![IMAGEN INICIO](img/inicio.png)

# %% [markdown]
# ## 3. Creación de visualizaciones

# %% [markdown]
# ### **¿Qué es una visualización en Tableau?**
#
# Una visualización es una representación gráfica de los datos que permite detectar patrones, comparar valores y comunicar información de forma visual.
# En Tableau, las visualizaciones se crean arrastrando dimensiones y medidas a las estanterías de Filas (Rows) y Columnas (Columns).

# %% [markdown]
# | Tipo de gráfico                  | Cuándo usarlo                        | Ejemplo                             |
# | -------------------------------- | ------------------------------------ | ----------------------------------- |
# | **Gráfico de barras**            | Comparar categorías o subcategorías. | Ventas por región.                  |
# | **Gráfico de líneas**            | Mostrar evolución en el tiempo.      | Ventas mensuales.                   |
# | **Gráfico de dispersión**        | Analizar relaciones entre variables. | Ventas vs. Beneficio.               |
# | **Mapa geográfico**              | Visualizar datos por ubicación.      | Ventas por país o ciudad.           |
# | **Gráfico circular (pie chart)** | Mostrar proporciones simples.        | Porcentaje de ventas por categoría. |

# %% [markdown]
# ## 4. Dashboards e interactividad

# %% [markdown]
# ### **¿Qué es un dashboard en Tableau?**
#
# Un dashboard es una vista unificada que reúne varias visualizaciones, controles y textos para contar una historia o facilitar el análisis interactivo.
#
# En otras palabras: un dashboard es una “ventana de control” donde el usuario puede explorar los datos sin modificar las hojas originales.
#
# 💡 Los dashboards son ideales para resumir resultados, comparar indicadores y crear experiencias visuales interactivas.

# %% [markdown]
# | Elemento                              | Descripción                                                                                                          |
# | ------------------------------------- | -------------------------------------------------------------------------------------------------------------------- |
# | **Panel de Objetos**                  | Contiene las visualizaciones (hojas), textos, imágenes, filtros y contenedores que se pueden arrastrar al dashboard. |
# | **Área de Diseño**                    | Lugar donde se colocan las hojas y objetos; es el lienzo principal del dashboard.                                    |
# | **Contenedores (Containers)**         | Permiten agrupar objetos horizontal o verticalmente para alinear y organizar elementos.                              |
# | **Controles de tamaño y disposición** | Ajustes de tamaño del dashboard, rejilla, estilo, espaciado y disposición de objetos.                                |

# %% [markdown]
# ###  **Pasos para crear un dashboard en Tableau**
#
# 1. **Crear un nuevo dashboard**
#    - En la parte inferior de Tableau, haz clic en el ícono **“New Dashboard”**.
#
# 2. **Seleccionar las hojas**
#    - En el panel izquierdo, verás tus hojas (`Sheet 1`, `Sheet 2`, `Sheet 3`, etc.).
#
# 3. **Agregar visualizaciones al dashboard**
#    - Arrastra las visualizaciones creadas en el Bloque 3 hacia el área central.
#    **Ejemplo:**
#      - Arrastra el gráfico de barras (**Ventas por Categoría**).
#      - Luego el gráfico de líneas (**Tendencia Mensual**).
#      - Y finalmente el mapa (**Ventas por Región**).
#
# 4. **Ajustar el tamaño del dashboard**
#    - En la parte inferior izquierda, selecciona **Size → Automatic** o elige dimensiones fijas (por ejemplo, 1200x800 px).
#
# 5. **Añadir un título general**
#    - Usa el objeto **Text** → escribe:
#      > “Análisis de Ventas — Superstore”
#    - Ajusta fuente, color y alineación según prefieras.
#
# 6. **Alinear los gráficos**
#    - Usa **containers** (horizontales o verticales) si quieres organizar mejor los gráficos y mantener un layout coherente.
#
# #### Resultado esperado
# Un tablero con **tres visualizaciones organizadas de forma coherente** y un **título superior**.

# %% [markdown]
# ### **Agregando interactividad**
#
# Los dashboards en Tableau pueden incluir elementos interactivos que permiten al usuario filtrar o destacar información.
#
# | Tipo                               | Descripción                                                                     | Ejemplo                                                           |
# | ---------------------------------- | ------------------------------------------------------------------------------- | ----------------------------------------------------------------- |
# | **Filtros**                        | Permiten seleccionar subconjuntos de datos desde un gráfico o menú desplegable. | Filtro por región o categoría.                                    |
# | **Acciones de resaltado**          | Enfatizan datos relacionados al pasar el ratón o seleccionar un elemento.       | Al hacer clic en una categoría, se resaltan las ventas asociadas. |
# | **Acciones de filtro entre hojas** | Un gráfico controla los datos que se muestran en otro.                          | Seleccionar una región en el mapa filtra los gráficos de ventas.  |
# | **Acciones de URL**                | Abren enlaces externos al interactuar con un elemento.                          | Clic en una región → abre una página web o informe detallado.     |

# %% [markdown]
# ### **Cómo agregar interactividad paso a paso**
#
# 1. **Abrir el menú de acciones**
#    - En el menú superior, selecciona:
#      **Dashboard → Actions... (Acciones...)**
#
# 2. **Agregar un filtro**
#    - Haz clic en **Add Action → Filter (Filtro)**.
#
# 3. **Configurar la acción**
#    - **Fuente:** la hoja que actuará como filtro (por ejemplo, el mapa).
#    - **Destino:** las hojas afectadas (por ejemplo, el gráfico de barras y el de líneas).
#    - **Modo de activación:** “Select” (clic) o “Hover” (pasar el mouse).
#
# 4. **Probar la interactividad**
#    - Haz clic en una región del mapa; los demás gráficos deben actualizarse automáticamente.
#
#
# ### 💡 Alternativa: agregar un control de filtro directamente
#
# - Clic derecho en un campo (por ejemplo, **Category**) → **Show Filter**.
# - Aparecerá un **menú desplegable** en el dashboard que permite filtrar los datos al instante.
