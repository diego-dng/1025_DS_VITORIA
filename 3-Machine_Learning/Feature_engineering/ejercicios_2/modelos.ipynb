# %% [markdown]
# # MODELOS.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn import metrics

# %%
df = pd.read_csv("data/datos_procesados.csv")
df
# Out:
#              make            model  \
# 0         CITROEN               C1
# 1            FORD  Transit Connect
# 2      VOLKSWAGEN        Caravelle
# 3            FORD          Transit
# 4         PEUGEOT             3008
# ...           ...              ...
# 41240     HYUNDAI              i30
# 41241     RENAULT           Laguna
# 41242     PEUGEOT              108
# 41243        AUDI              RS4
# 41244     CITROEN               C2
#
#                                                  version  price      fuel  \
# 0                 CITROEN C1 PureTech 60KW 82CV Feel 5p.   6200  Gasolina
# 1      FORD Transit Connect Van 1.5 TDCi 100cv Ambien...   7851    Diésel
# 2      VOLKSWAGEN Caravelle Largo 2.0 TDI 140 Comfort...  19426    Diésel
# 3      FORD Transit 350 96kW L4 Ambiente Propulsion T...  22850    Diésel
# 4             PEUGEOT 3008 Style 1.2 PureTech 130 SS 5p.  11490  Gasolina
# ...                                                  ...    ...       ...
# 41240        HYUNDAI i30 1.4 TGDI Tecno Fastback DCT 5p.  18490  Gasolina
# 41241  RENAULT Laguna Coupe Limited 2.0 Energy dCi 15...  14500    Diésel
# 41242           PEUGEOT 108 TOP Allure VTi 52kW 72CV 5p.  11000  Gasolina
# 41243           AUDI RS4 Avant 4.2 FSI 450cv quattro 5p.  47900  Gasolina
# 41244                    CITROEN C2 1.4 HDI VTR Plus 3p.   2790    Diésel
#
#          year     kms  power  doors       shift  \
# 0      2017.0   50071   82.0      5      Manual
# 1      2016.0  103000  100.0      4      Manual
# 2      2014.0  120000  140.0      4      Manual
# 3      2017.0  107000  130.0      2      Manual
# 4      2016.0   78665  130.0      5      Manual
# ...       ...     ...    ...    ...         ...
# 41240  2018.0   47000  140.0      5  Automático
# 41241  2015.0   68750  150.0      2      Manual
# 41242  2019.0   21422   72.0      5      Manual
# 41243  2013.0   47900  450.0      5  Automático
# 41244  2006.0  106000   70.0      3      Manual
#
#                                 color  is_professional   province
# 0                              Blanco             True   Tenerife
# 1                              Blanco             True  Barcelona
# 2                              Blanco             True    Navarra
# 3                              Blanco             True    Sevilla
# 4                              Blanco             True     Madrid
# ...                               ...              ...        ...
# 41240                    Gris / Plata             True     Málaga
# 41241  KNG Gris Casiopea (metalizado)             True     Málaga
# 41242                    Gris / Plata             True     Huelva
# 41243        Gris / Plata (Antracita)             True       Lugo
# 41244                           Negro             True  Barcelona
#
# [41245 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41245 entries, 0 to 41244
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   make             41245 non-null  object
#  1   model            41245 non-null  object
#  2   version          41245 non-null  object
#  3   price            41245 non-null  int64
#  4   fuel             41245 non-null  object
#  5   year             41245 non-null  float64
#  6   kms              41245 non-null  int64
#  7   power            41245 non-null  float64
#  8   doors            41245 non-null  int64
#  9   shift            41245 non-null  object
#  10  color            41245 non-null  object
#  11  is_professional  41245 non-null  bool
#  12  province         41245 non-null  object
# dtypes: bool(1), float64(2), int64(3), object(7)
# memory usage: 3.8+ MB

# %% [markdown]
# ## X, y, train y test

# %%
X = df[["year", "kms", "power", "doors", "is_professional"]]
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (32996, 5)
# (32996,)
# (8249, 5)
# (8249,)

# %% [markdown]
# ## Linear regresion

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
pred_lr = lr.predict(X_test)

print(metrics.mean_absolute_error(y_test, pred_lr))
# Out:
# 4983.646912672643
